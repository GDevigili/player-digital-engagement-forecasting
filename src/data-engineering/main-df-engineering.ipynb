# %% [markdown]
# # Data Preparation
#
# Notebook que irá conter o código utilizado para a preparação dos dados do projeto.
#
# os dados "crus" estão localizados em **/src/data/raw-data** e os dados tratados devem ser salvos em **/src/data/processed-data**

# %%
import pandas as pd
import numpy as np

import pickle as pkl

from joblib import Parallel, delayed
from pathlib import Path

# %%
# File paths for working locally
raw_data_path = '../data/raw-data/'
processed_data_path = '../data/processed-data/'

# %% [markdown]
# ### Auxiliary functions
#
# These functions were taken from the getting started notebook from kaggle

# %%
# Helper function to unpack json found in daily data
def unpack_json(json_str):
    return pd.DataFrame() if pd.isna(json_str) else pd.read_json(json_str)


def unpack_data(data, dfs=None, n_jobs=-1):
    if dfs is not None:
        data = data.loc[:, dfs]
    unnested_dfs = {}
    for name, column in data.iteritems():
        daily_dfs = Parallel(n_jobs=n_jobs)(
            delayed(unpack_json)(item) for date, item in column.iteritems())
        df = pd.concat(daily_dfs)
        unnested_dfs[name] = df
    return unnested_dfs

# %% [markdown]
# ## Loading the Datasets

# %%
dataset_names = {
    'Awards': 'awards.csv', 
    'Example': 'example_test.csv', 
    'Players': 'players.csv',
    'Seasons': 'seasons.csv', 
    'Teams': 'teams.csv', 
    'Train': 'train.csv'
}
for key in dataset_names:
  dataset_names[key] = raw_data_path + dataset_names[key]
dataset_names
# Out:
# {'Awards': '../data/raw-data/awards.csv',
#  'Example': '../data/raw-data/example_test.csv',
#  'Players': '../data/raw-data/players.csv',
#  'Seasons': '../data/raw-data/seasons.csv',
#  'Teams': '../data/raw-data/teams.csv',
#  'Train': '../data/raw-data/train.csv'}

# %%
df_test = pd.read_csv(dataset_names['Example'])

# %%
df_test.info()
df_test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    5 non-null      int64
#  1   games                   5 non-null      object
#  2   rosters                 5 non-null      object
#  3   playerBoxScores         5 non-null      object
#  4   teamBoxScores           5 non-null      object
#  5   transactions            4 non-null      object
#  6   standings               5 non-null      object
#  7   awards                  1 non-null      object
#  8   events                  5 non-null      object
#  9   playerTwitterFollowers  0 non-null      float64
#  10  teamTwitterFollowers    0 non-null      float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 568.0+ bytes
#        date                                              games  \
# 0  20210426  [{"gamePk":634374,"gameType":"R","season":2021...
# 1  20210427  [{"gamePk":634318,"gameType":"R","season":2021...
# 2  20210428  [{"gamePk":634309,"gameType":"R","season":2021...
# 3  20210429  [{"gamePk":634330,"gameType":"R","season":2021...
# 4  20210430  [{"gamePk":634287,"gameType":"R","season":2021...
#
#                                              rosters  \
# 0  [{"playerId":405395,"gameDate":"2021-04-26","t...
# 1  [{"playerId":443558,"gameDate":"2021-04-27","t...
# 2  [{"playerId":429722,"gameDate":"2021-04-28","t...
# 3  [{"playerId":405395,"gameDate":"2021-04-29","t...
# 4  [{"playerId":405395,"gameDate":"2021-04-30","t...
#
#                                      playerBoxScores  \
# 0  [{"home":1,"gamePk":634377,"gameDate":"2021-04...
# 1  [{"home":1,"gamePk":634320,"gameDate":"2021-04...
# 2  [{"home":1,"gamePk":634310,"gameDate":"2021-04...
# 3  [{"home":1,"gamePk":634330,"gameDate":"2021-04...
# 4  [{"home":1,"gamePk":634305,"gameDate":"2021-04...
#
#                                        teamBoxScores  \
# 0  [{"home":1,"teamId":139,"gamePk":634343,"gameD...
# 1  [{"home":1,"teamId":117,"gamePk":634333,"gameD...
# 2  [{"home":0,"teamId":111,"gamePk":634310,"gameD...
# 3  [{"home":0,"teamId":119,"gamePk":634346,"gameD...
# 4  [{"home":1,"teamId":135,"gamePk":634303,"gameD...
#
#                                         transactions  \
# 0  [{"transactionId":480386,"playerId":543685,"pl...
# 1  [{"transactionId":480456,"playerId":642162,"pl...
# 2  [{"transactionId":480728,"playerId":545358,"pl...
# 3  [{"transactionId":480993,"playerId":606965,"pl...
# 4                                                NaN
#
#                                            standings  \
# 0  [{"season":2021,"gameDate":"2021-04-26","divis...
# 1  [{"season":2021,"gameDate":"2021-04-27","divis...
# 2  [{"season":2021,"gameDate":"2021-04-28","divis...
# 3  [{"season":2021,"gameDate":"2021-04-29","divis...
# 4  [{"season":2021,"gameDate":"2021-04-30","divis...
#
#                                               awards  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [{"awardId":"NLRRELMON","awardName":"NL Reliev...
#
#                                               events  playerTwitterFollowers  \
# 0  [{"gamePk":634433,"gameDate":"2021-04-26","gam...                     NaN
# 1  [{"gamePk":634332,"gameDate":"2021-04-27","gam...                     NaN
# 2  [{"gamePk":634317,"gameDate":"2021-04-28","gam...                     NaN
# 3  [{"gamePk":634346,"gameDate":"2021-04-29","gam...                     NaN
# 4  [{"gamePk":634327,"gameDate":"2021-04-30","gam...                     NaN
#
#    teamTwitterFollowers
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %% [markdown]
# #### Column: games

# %%
unpack_json(df_test['games'][0])
# Out:
#     gamePk gameType  season    gameDate           gameTimeUTC  resumeDate  \
# 0   634374        R    2021  2021-04-26  2021-04-27T01:45:00Z         NaN
# 1   634377        R    2021  2021-04-26  2021-04-27T00:05:00Z         NaN
# 2   634433        R    2021  2021-04-26  2021-04-26T23:05:00Z         NaN
# 3   634363        R    2021  2021-04-26  2021-04-27T02:10:00Z         NaN
# 4   634402        R    2021  2021-04-26  2021-04-26T23:10:00Z         NaN
# 5   634461        R    2021  2021-04-26  2021-04-26T23:40:00Z         NaN
# 6   634343        R    2021  2021-04-26  2021-04-26T23:10:00Z         NaN
# 7   634345        R    2021  2021-04-26  2021-04-26T23:45:00Z         NaN
# 8   634382        R    2021  2021-04-26  2021-04-27T00:10:00Z         NaN
# 9   634394        R    2021  2021-04-26  2021-04-26T22:10:00Z         NaN
# 10  634451        R    2021  2021-04-26  2021-04-26T17:10:00Z         NaN
#
#     resumedFrom codedGameState detailedGameState  isTie  ...  homeWinner  \
# 0           NaN              F             Final  False  ...        True
# 1           NaN              F             Final  False  ...       False
# 2           NaN              F             Final  False  ...        True
# 3           NaN              F             Final  False  ...       False
# 4           NaN              F             Final  False  ...        True
# 5           NaN              F             Final  False  ...       False
# 6           NaN              F             Final  False  ...       False
# 7           NaN              F             Final  False  ...       False
# 8           NaN              F             Final  False  ...        True
# 9           NaN              F             Final  False  ...        True
# 10          NaN              F             Final  False  ...       False
#
#    homeScore awayId               awayName  awayAbbrev awayWins  awayLosses  \
# 0         12    115       Colorado Rockies         COL        8          14
# 1          4    108     Los Angeles Angels         LAA       11          10
# 2          4    147       New York Yankees         NYY        9          13
# 3          3    113        Cincinnati Reds         CIN       10          12
# 4          8    112           Chicago Cubs         CHC       10          12
# 5          0    146          Miami Marlins         MIA       10          12
# 6          1    133      Oakland Athletics         OAK       15           8
# 7          1    143  Philadelphia Phillies         PHI       11          11
# 8          5    136       Seattle Mariners         SEA       13          10
# 9          5    142        Minnesota Twins         MIN        7          14
# 10         2    118     Kansas City Royals          KC       14           7
#
#    awayWinPct awayWinner  awayScore
# 0       0.364      False          0
# 1       0.524       True          9
# 2       0.409      False          2
# 3       0.455       True          5
# 4       0.455      False          7
# 5       0.455       True          8
# 6       0.652       True          2
# 7       0.500       True          2
# 8       0.565      False          2
# 9       0.333      False          3
# 10      0.667       True          3
#
# [11 rows x 32 columns]

# %% [markdown]
# #### Column: rosters

# %%
unpack_json(df_test['rosters'][0]).head()
# Out:
#    playerId    gameDate  teamId statusCode  status
# 0    405395  2021-04-26     108          A  Active
# 1    408234  2021-04-26     116          A  Active
# 2    444482  2021-04-26     109          A  Active
# 3    445276  2021-04-26     119          A  Active
# 4    446334  2021-04-26     137          A  Active

# %%
unpack_json(df_test['playerBoxScores'][0]).head()
# Out:
#    home  gamePk    gameDate           gameTimeUTC  teamId            teamName  \
# 0     1  634377  2021-04-26  2021-04-27T00:05:00Z     140       Texas Rangers
# 1     0  634451  2021-04-26  2021-04-26T17:10:00Z     118  Kansas City Royals
# 2     1  634377  2021-04-26  2021-04-27T00:05:00Z     140       Texas Rangers
# 3     0  634382  2021-04-26  2021-04-27T00:10:00Z     136    Seattle Mariners
# 4     1  634377  2021-04-26  2021-04-27T00:05:00Z     140       Texas Rangers
#
#    playerId          playerName  jerseyNum  positionCode  ...  \
# 0    624431        Jose Trevino         23             2  ...
# 1    641531       Hunter Dozier         17             9  ...
# 2    669256          Nick Solak         15             4  ...
# 3    641786          Kyle Lewis          1             8  ...
# 4    643396  Isiah Kiner-Falefa          9             6  ...
#
#   catchersInterferencePitching sacBuntsPitching  sacFliesPitching  saves  \
# 0                          NaN              NaN               NaN    NaN
# 1                          NaN              NaN               NaN    NaN
# 2                          NaN              NaN               NaN    NaN
# 3                          NaN              NaN               NaN    NaN
# 4                          NaN              NaN               NaN    NaN
#
#    holds  blownSaves  assists  putOuts  errors  chances
# 0    NaN         NaN        0        5       0        5
# 1    NaN         NaN        0        1       0        1
# 2    NaN         NaN        1        4       0        5
# 3    NaN         NaN        0        1       0        1
# 4    NaN         NaN        3        1       0        4
#
# [5 rows x 85 columns]

# %% [markdown]
# #### Column: playerBoxScores

# %%
unpack_json(df_test['playerBoxScores'][0]).head()
# Out:
#    home  gamePk    gameDate           gameTimeUTC  teamId            teamName  \
# 0     1  634377  2021-04-26  2021-04-27T00:05:00Z     140       Texas Rangers
# 1     0  634451  2021-04-26  2021-04-26T17:10:00Z     118  Kansas City Royals
# 2     1  634377  2021-04-26  2021-04-27T00:05:00Z     140       Texas Rangers
# 3     0  634382  2021-04-26  2021-04-27T00:10:00Z     136    Seattle Mariners
# 4     1  634377  2021-04-26  2021-04-27T00:05:00Z     140       Texas Rangers
#
#    playerId          playerName  jerseyNum  positionCode  ...  \
# 0    624431        Jose Trevino         23             2  ...
# 1    641531       Hunter Dozier         17             9  ...
# 2    669256          Nick Solak         15             4  ...
# 3    641786          Kyle Lewis          1             8  ...
# 4    643396  Isiah Kiner-Falefa          9             6  ...
#
#   catchersInterferencePitching sacBuntsPitching  sacFliesPitching  saves  \
# 0                          NaN              NaN               NaN    NaN
# 1                          NaN              NaN               NaN    NaN
# 2                          NaN              NaN               NaN    NaN
# 3                          NaN              NaN               NaN    NaN
# 4                          NaN              NaN               NaN    NaN
#
#    holds  blownSaves  assists  putOuts  errors  chances
# 0    NaN         NaN        0        5       0        5
# 1    NaN         NaN        0        1       0        1
# 2    NaN         NaN        1        4       0        5
# 3    NaN         NaN        0        1       0        1
# 4    NaN         NaN        3        1       0        4
#
# [5 rows x 85 columns]

# %% [markdown]
# #### Column: teamBoxScores

# %%
unpack_json(df_test['teamBoxScores'][0]).head()
# Out:
#    home  teamId  gamePk    gameDate           gameTimeUTC  flyOuts  \
# 0     1     139  634343  2021-04-26  2021-04-26T23:10:00Z        5
# 1     1     117  634382  2021-04-26  2021-04-27T00:10:00Z        4
# 2     1     138  634345  2021-04-26  2021-04-26T23:45:00Z        3
# 3     1     116  634451  2021-04-26  2021-04-26T17:10:00Z        5
# 4     0     147  634433  2021-04-26  2021-04-26T23:05:00Z        6
#
#    groundOuts  runsScored  doubles  triples  ...  hitBatsmen  balks  \
# 0           7           1        0        0  ...           2      0
# 1          10           5        1        0  ...           1      0
# 2           7           1        0        0  ...           0      0
# 3           6           2        2        2  ...           0      0
# 4           9           2        2        0  ...           1      0
#
#    wildPitches  pickoffsPitching  rbiPitching  inheritedRunners  \
# 0            0                 0            2                 0
# 1            0                 0            2                 0
# 2            0                 0            2                 0
# 3            0                 0            3                 0
# 4            0                 0            3                 0
#
#    inheritedRunnersScored  catchersInterferencePitching  sacBuntsPitching  \
# 0                       0                             0                 0
# 1                       0                             0                 0
# 2                       0                             0                 0
# 3                       0                             0                 1
# 4                       0                             0                 0
#
#    sacFliesPitching
# 0                 0
# 1                 0
# 2                 0
# 3                 1
# 4                 0
#
# [5 rows x 57 columns]

# %% [markdown]
# #### Column: transactions

# %%
unpack_json(df_test['transactions'][0]).head()
# Out:
#    transactionId  playerId       playerName       date  fromTeamId  \
# 0         480386    543685   Anthony Rendon 2021-04-26         NaN
# 1         479907    664852         Jay Flaa 2021-04-26      3282.0
# 2         480224    592858       Rowan Wick 2021-04-26         NaN
# 3         480378    519222    Austin Romine 2021-04-26         NaN
# 4         480380    656547  Jonathan Holder 2021-04-26         NaN
#
#                       fromTeamName  toTeamId          toTeamName  \
# 0                             None       108  Los Angeles Angels
# 1  Orioles Alternate Training Site       110   Baltimore Orioles
# 2                             None       112        Chicago Cubs
# 3                             None       112        Chicago Cubs
# 4                             None       112        Chicago Cubs
#
#   effectiveDate resolutionDate typeCode       typeDesc  \
# 0    2021-04-26     2021-04-26       SC  Status Change
# 1    2021-04-26           None       SE       Selected
# 2    2021-04-26     2021-04-26       SC  Status Change
# 3    2021-04-26     2021-04-26       SC  Status Change
# 4    2021-04-26     2021-04-26       SC  Status Change
#
#                                          description
# 0  Los Angeles Angels activated 3B Anthony Rendon...
# 1  Baltimore Orioles selected the contract of RHP...
# 2  Chicago Cubs placed RHP Rowan Wick on the 60-d...
# 3  Chicago Cubs placed C Austin Romine on the 10-...
# 4  Chicago Cubs placed RHP Jonathan Holder on the...

# %% [markdown]
# #### Column: standings

# %%
unpack_json(df_test['standings'][0]).head()
# Out:
#    season    gameDate  divisionId  teamId        teamName streakCode  \
# 0    2021  2021-04-26         205     112    Chicago Cubs         L3
# 1    2021  2021-04-26         204     146   Miami Marlins         W1
# 2    2021  2021-04-26         204     121   New York Mets         W1
# 3    2021  2021-04-26         200     140   Texas Rangers         L4
# 4    2021  2021-04-26         204     144  Atlanta Braves         W1
#
#    divisionRank  leagueRank  wildCardRank leagueGamesBack  ... grassLosses  \
# 0             4          11           9.0             4.5  ...          12
# 1             4          13          11.0             4.5  ...          12
# 2             1           5           NaN             3.0  ...           8
# 3             5          13          10.0             6.0  ...           6
# 4             3          10           8.0             4.5  ...          12
#
#   turfWins  turfLosses  divWins  divLosses  alWins  alLosses  nlWins  \
# 0        0           0        6          9     NaN       NaN     6.0
# 1        0           0        4          2     1.0       3.0     1.0
# 2        0           0        7          4     NaN       NaN     0.0
# 3        6           8        2          2     1.0       5.0     1.0
# 4        0           0        5          8     3.0       1.0     3.0
#
#    nlLosses xWinLossPct
# 0       9.0       0.400
# 1       3.0       0.250
# 2       3.0       0.000
# 3       5.0       0.167
# 4       1.0       0.750
#
# [5 rows x 47 columns]

# %% [markdown]
# #### Column: awards

# %%
unpack_json(df_test['awards'][4]).head()
# Out:
#      awardId                 awardName   awardDate  awardSeason  playerId  \
# 0  NLRRELMON  NL Reliever of the Month  2021-04-30         2021    453343
# 1      NLROM    NL Rookie of the Month  2021-04-30         2021    669432
# 2    NLPITOM   NL Pitcher of the Month  2021-04-30         2021    594798
# 3      NLPOM    NL Player of the Month  2021-04-30         2021    660670
# 4  ALRRELMON  AL Reliever of the Month  2021-04-30         2021    598264
#
#          playerName  awardPlayerTeamId
# 0     Mark Melancon                135
# 1     Trevor Rogers                146
# 2      Jacob deGrom                121
# 3  Ronald Acuna Jr.                144
# 4       Matt Barnes                111

# %% [markdown]
# #### Column: events

# %%
unpack_json(df_test['events'][0]).head()
# Out:
#    gamePk    gameDate           gameTimeUTC  season gameType playId  eventId  \
# 0  634433  2021-04-26  2021-04-26T23:05:00Z    2021        R   None        8
# 1  634451  2021-04-26  2021-04-26T17:10:00Z    2021        R   None        0
# 2  634343  2021-04-26  2021-04-26T23:10:00Z    2021        R   None        0
# 3  634433  2021-04-26  2021-04-26T23:05:00Z    2021        R   None        0
# 4  634394  2021-04-26  2021-04-26T22:10:00Z    2021        R   None        4
#
#    inning halfInning  homeScore  ...  vX0 vY0  vZ0   x   y  x0  y0  z0  \
# 0       6     bottom          2  ...  NaN NaN  NaN NaN NaN NaN NaN NaN
# 1       7     bottom          2  ...  NaN NaN  NaN NaN NaN NaN NaN NaN
# 2       7     bottom          1  ...  NaN NaN  NaN NaN NaN NaN NaN NaN
# 3       8     bottom          4  ...  NaN NaN  NaN NaN NaN NaN NaN NaN
# 4       8        top          2  ...  NaN NaN  NaN NaN NaN NaN NaN NaN
#
#      type  zone
# 0  action   NaN
# 1  action   NaN
# 2  action   NaN
# 3  action   NaN
# 4  action   NaN
#
# [5 rows x 71 columns]
